# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $$f(x)=1.2x+0.8$$

# %%
x=np.linspace(0,5,50)

# %%
y=1.2*x+0.8

# %%
plt.scatter(x,y)
plt.plot(x,y,'purple')

# %%
y=1.2*x+0.8+ 0.6*np.random.randn(50) #做noise項

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.plot(x,1.2*x+0.8,'purple')

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
y
# Out:
# array([ 0.28816758,  0.78833647,  1.21256453,  1.10992863,  1.88346341,
#         0.64531091,  1.16878474,  1.92296866,  2.64091978,  1.06668846,
#         0.95096386, -0.01697719,  2.20152832,  0.95564458,  2.78233379,
#         1.42661124,  3.37244142,  3.76818544,  3.32071016,  2.59813921,
#         2.823603  ,  3.39213208,  2.72128645,  4.40532333,  3.46093597,
#         4.33124591,  4.19748812,  5.2076061 ,  5.11476668,  3.46383672,
#         5.55914264,  3.74532361,  6.03398049,  5.53019381,  4.44802642,
#         6.30656938,  5.61700584,  6.11383268,  5.77346718,  5.96971981,
#         5.44764926,  5.3865033 ,  5.82153321,  7.2171323 ,  6.37924243,
#         6.21068928,  6.50925576,  5.87444361,  5.53876084,  7.35598837])

# %%
from sklearn.linear_model import LinearRegression

# %%
regr=LinearRegression()

# %%
X=x.reshape(50,1) #重整陣列

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr.predict(X)

# %%
plt.scatter(x,y)
plt.plot(x,Y,'yellow')
plt.plot(x,1.2*x+0.8,'red')

# %%
from ipywidgets import interact

# %%
X=np.linspace(0,5,1000)
def my_fit(n):
    Y=4*np.sin(n*X)+4
    plt.scatter(x,y)
    plt.plot(X,Y,'r')
    plt.show()

# %%
my_fit(5)

# %%
interact(my_fit,n=(1,100))
# Out:
# interactive(children=(IntSlider(value=50, description='n', min=1), Output()), _dom_classes=('widget-interact',…
# <function __main__.my_fit(n)>

# %%
x=np.linspace(0,5,100)
y=1.2*x+0.8+0.5*np.random.randn(100)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split #訓練資料、測試資料

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                              test_size=0.2,
                                              random_state=94)

# %%
len(x_train)
# Out:
# 80

# %%
len(x_test)
# Out:
# 20

# %%
x_train=x_train.reshape(80,1)

# %%
x_test.shape=(20,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regr=LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,regr.predict(x_train),'r')

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,regr.predict(x_test),'y')

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
X=boston.data
Y=boston.target

# %%
len(X)
# Out:
# 506

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,
                                              test_size=0.3,
                                              random_state=94)

# %%
regr=LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=regr.predict(x_test)

# %%
plt.scatter(y_test,y_predict)
plt.plot([0,50],[0,50],'g')
plt.xlabel('True Price')
plt.ylabel('Predicted Price')
# Out:
# Text(0, 0.5, 'Predicted Price')

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
L=['a','b','c']

# %%
for i in range(3):
    print(i+1,L[i])
# Out:
# 1 a
# 2 b
# 3 c

# %%
list(enumerate(L))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
for i in enumerate(L):
    print(i)
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')

# %%
for i,s in enumerate(L):
    print(i+1,s)
# Out:
# 1 a
# 2 b
# 3 c

# %%
x=np.linspace(-10,10,200)

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,x)

plt.subplot(2,2,4)
plt.plot(x,x**2)

# %%
plt.figure(figsize=(8,10))
for i,feature in enumerate(boston.feature_names):
    plt.subplot(5,3,i+1)
    plt.scatter(X[:,i],Y,s=1)
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.tight_layout()
