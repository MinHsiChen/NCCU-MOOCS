# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# %ls
# Out:
#  磁碟區 C 中的磁碟沒有標籤。
#  磁碟區序號:  24CA-7064
#
#  C:\Users\USER\Python practice 的目錄
#
# 2022/04/07  下午 08:01    <DIR>          .
# 2022/04/07  下午 08:01    <DIR>          ..
# 2022/04/07  下午 07:28    <DIR>          .ipynb_checkpoints
# 2022/04/07  下午 03:29            70,343 week1.ipynb
# 2022/04/07  下午 03:28            18,077 week2.ipynb
# 2022/04/07  下午 04:36           194,578 week3.ipynb
# 2022/04/07  下午 07:27            42,390 week4.ipynb
# 2022/04/07  下午 07:59             2,038 week5.ipynb
# 2022/04/07  下午 08:01               107 模擬的段考成績.csv
#                6 個檔案         327,533 位元組
#                3 個目錄  169,251,782,656 位元組可用

# %%
df=pd.read_csv('模擬的段考成績.csv')

# %%
df.head()
# Out:
#     姓名  國文  英文  數學
# 0  陳旻熙  91  75  72
# 1  許芸軒  79  82  72
# 2  浦悅軒  84  88  74
# 3  劉子僑  78  84  61

# %%
df['國文']
# Out:
# 0    91
# 1    79
# 2    84
# 3    78
# Name: 國文, dtype: int64

# %%
df.國文
# Out:
# 0    91
# 1    79
# 2    84
# 3    78
# Name: 國文, dtype: int64

# %%
cg=df.國文.values

# %%
cg
# Out:
# array([91, 79, 84, 78], dtype=int64)

# %%
cg.mean()
# Out:
# 83.0

# %%
cg.std()
# Out:
# 5.1478150704935

# %%
df.國文.plot()
# Out:
# <AxesSubplot:>

# %%
df.國文.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               國文         英文         數學
# count   4.000000   4.000000   4.000000
# mean   83.000000  82.250000  69.750000
# std     5.944185   5.439056   5.909033
# min    78.000000  75.000000  61.000000
# 25%    78.750000  80.250000  69.250000
# 50%    81.500000  83.000000  72.000000
# 75%    85.750000  85.000000  72.500000
# max    91.000000  88.000000  74.000000

# %%
df.corr()
# Out:
#           國文        英文        數學
# 國文  1.000000 -0.618606  0.540935
# 英文 -0.618606  1.000000 -0.080379
# 數學  0.540935 -0.080379  1.000000

# %%
df.國文.corr(df.數學)
# Out:
# 0.5409347817899427

# %%
df['總分']=df[['國文','英文','數學']].sum(1)

# %%
df.head()
# Out:
#     姓名  國文  英文  數學   總分
# 0  陳旻熙  91  75  72  238
# 1  許芸軒  79  82  72  233
# 2  浦悅軒  84  88  74  246
# 3  劉子僑  78  84  61  223

# %%
df['主科']=df.英文*1.5+df.數學*1.25

# %%
df.head()
# Out:
#     姓名  國文  英文  數學   總分      主科
# 0  陳旻熙  91  75  72  238  202.50
# 1  許芸軒  79  82  72  233  213.00
# 2  浦悅軒  84  88  74  246  224.50
# 3  劉子僑  78  84  61  223  202.25

# %%
df.sort_values(by='總分',ascending=False).head(2)
# Out:
#     姓名  國文  英文  數學   總分     主科
# 2  浦悅軒  84  88  74  246  224.5
# 0  陳旻熙  91  75  72  238  202.5

# %%
df.sort_values(by=['主科','總分'],ascending=False).head()
# Out:
#     姓名  國文  英文  數學   總分      主科
# 2  浦悅軒  84  88  74  246  224.50
# 1  許芸軒  79  82  72  233  213.00
# 0  陳旻熙  91  75  72  238  202.50
# 3  劉子僑  78  84  61  223  202.25

# %%
mydata=np.random.randn(4,3)

# %%
mydata
# Out:
# array([[ 0.38784187,  0.70633191,  1.25898967],
#        [ 0.961502  ,  1.16226102, -0.94861355],
#        [-0.88816831, -1.99320461, -0.73551123],
#        [-0.09162134, -0.58680161, -0.45711237]])

# %%
list('ABC')
# Out:
# ['A', 'B', 'C']

# %%
df1=pd.DataFrame(mydata,columns=list('ABC'))

# %%
df1
# Out:
#           A         B         C
# 0  0.387842  0.706332  1.258990
# 1  0.961502  1.162261 -0.948614
# 2 -0.888168 -1.993205 -0.735511
# 3 -0.091621 -0.586802 -0.457112

# %%
df2=pd.DataFrame(np.random.randn(3,3),columns=list('ABC'))

# %%
df2
# Out:
#           A         B         C
# 0 -0.248332 -1.167069 -1.202073
# 1  1.964517 -0.017418  0.578267
# 2  1.797413  1.149120  1.232278

# %%
df3=pd.concat([df1,df2],axis=0)

# %%
df3
# Out:
#           A         B         C
# 0  0.387842  0.706332  1.258990
# 1  0.961502  1.162261 -0.948614
# 2 -0.888168 -1.993205 -0.735511
# 3 -0.091621 -0.586802 -0.457112
# 0 -0.248332 -1.167069 -1.202073
# 1  1.964517 -0.017418  0.578267
# 2  1.797413  1.149120  1.232278

# %%
df3.index=range(7)

# %%
df3
# Out:
#           A         B         C
# 0  0.387842  0.706332  1.258990
# 1  0.961502  1.162261 -0.948614
# 2 -0.888168 -1.993205 -0.735511
# 3 -0.091621 -0.586802 -0.457112
# 4 -0.248332 -1.167069 -1.202073
# 5  1.964517 -0.017418  0.578267
# 6  1.797413  1.149120  1.232278

# %%
df4=pd.concat([df1,df2],axis=1)

# %%
df4
# Out:
#           A         B         C         A         B         C
# 0  0.387842  0.706332  1.258990 -0.248332 -1.167069 -1.202073
# 1  0.961502  1.162261 -0.948614  1.964517 -0.017418  0.578267
# 2 -0.888168 -1.993205 -0.735511  1.797413  1.149120  1.232278
# 3 -0.091621 -0.586802 -0.457112       NaN       NaN       NaN

# %%
df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv')

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_state=df.groupby('State').count()

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values(by='Time',ascending=False)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# ...

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values(by='Time',ascending=False,inplace=True)

# %%
df_state.head(10)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_state[:10].Time.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df_state.Time.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df=pd.DataFrame(np.random.randn(5,3),
               index=list(range(1,6)),
                columns=list('ABC'))

# %%
df
# Out:
#           A         B         C
# 1 -0.928734  0.716500 -0.424662
# 2  0.864888  0.412550 -0.319294
# 3  1.327725  0.250354  1.673860
# 4  0.638869  0.977005 -0.572183
# 5  0.879985  0.583710 -0.026814

# %%
df[df.B>0]
# Out:
#           A         B         C
# 1 -0.928734  0.716500 -0.424662
# 2  0.864888  0.412550 -0.319294
# 3  1.327725  0.250354  1.673860
# 4  0.638869  0.977005 -0.572183
# 5  0.879985  0.583710 -0.026814

# %%
df.loc[2:3,'B':'C']
# Out:
#           B         C
# 2  0.412550 -0.319294
# 3  0.250354  1.673860

# %%
df.loc[2,'B']
# Out:
# 0.4125503586836435

# %%
df.loc[2,'B']=1

# %%
df
# Out:
#           A         B         C
# 1 -0.928734  0.716500 -0.424662
# 2  0.864888  1.000000 -0.319294
# 3  1.327725  0.250354  1.673860
# 4  0.638869  0.977005 -0.572183
# 5  0.879985  0.583710 -0.026814

# %%
df.loc[df.B>0,'C']=0

# %%
df
# Out:
#           A         B    C
# 1 -0.928734  0.716500  0.0
# 2  0.864888  1.000000  0.0
# 3  1.327725  0.250354  0.0
# 4  0.638869  0.977005  0.0
# 5  0.879985  0.583710  0.0

# %%
import pandas_datareader.data as web

# %%
df=web.DataReader('AAPL','yahoo',start='2012-9-1',end='2021-8-31')

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-08-31  23.878571  23.473213  23.830357  23.758572  338321200.0  20.431208
# 2012-09-04  24.112143  23.732143  23.777143  24.106071  367892000.0  20.730036
# 2012-09-05  24.155357  23.914286  24.127501  23.936787  336375200.0  20.584461
# 2012-09-06  24.224644  23.957144  24.041786  24.152500  391196400.0  20.769964
# 2012-09-07  24.374287  24.134644  24.216070  24.301430  329666400.0  20.898031

# %%
P=df['Adj Close']

# %%
P.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
r=P.diff()/P #計算報酬率

# %%
r[-100:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>
