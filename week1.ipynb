# %%
2**3 #2的3次方
# Out:
# 8

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
7%3
# Out:
# 1

# %%
# %pylab inline #讓python會更多數學
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([3,1,-7,4,9]) #畫圖

# %%
randn(16)
# Out:
# array([ 0.77145035, -0.55571153,  0.63602554, -0.21714141, -1.00143202,
#         0.95969789,  0.87492944,  0.23987288, -0.3409136 , -1.25651463,
#         0.45574569,  1.23994405,  1.65726232, -3.58709365,  0.16822305,
#        -2.1294934 ])

# %%
plot(randn(100))

# %%
plot([1,3,5,4,2],[9,7,5,6,8]) #(x,y)

# %% [markdown]
# 切換markdown可以作筆記!

# %% [markdown]
# # 大標題用一個井字
# ## 次標題兩個井字

# %% [markdown]
# ##分項說明
# * 用米字
# * ctrl + M 是切換markdown快捷鍵

# %% [markdown]
# ## 超連結方式
# 中括號是標題，小括號是連結

# %% [markdown]
# ## 插入圖片
# !中括號標題，小括號圖片連結

# %% [markdown]
# ## 數學符號
# 在數學符號前後加錢錢符號就可以了
# 如果要至中就前後各兩個
# $F(x)=x^5-4X^3+7$
# $$F(x)=x^5-4X^3+7$$

# %% [markdown]
# ## 定義串列list

# %%
L=[4,6,3,7,9]

# %%
plot(L)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12708/2705380849.py in <module>
# ----> 1 plot(L)
#
# NameError: name 'plot' is not defined

# %%
G=[11,22,33,44,55]

# %%
L+G
# Out:
# [4, 6, 3, 7, 9, 11, 22, 33, 44, 55]

# %%
L-G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12708/1154460852.py in <module>
# ----> 1 L-G
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
3*L
# Out:
# [4, 6, 3, 7, 9, 4, 6, 3, 7, 9, 4, 6, 3, 7, 9]

# %%
print('hello, world')
# Out:
# hello, world

# %%
name='陳旻熙'
print(name)
# Out:
# 陳旻熙

# %%
'hello, '+name+"!"
# Out:
# 'hello, 陳旻熙!'

# %%
emoji='٩(●ᴗ●)۶'

# %%
5*emoji
# Out:
# '٩(●ᴗ●)۶٩(●ᴗ●)۶٩(●ᴗ●)۶٩(●ᴗ●)۶٩(●ᴗ●)۶'

# %% [markdown]
# 用三引號中間可以換行

# %%
m = input('美金: ')
# Out:
# 美金: 100

# %%
float(m)*30.5 #浮點數
# Out:
# 3050.0

# %%
m = input('美金: ')
nt = float(m)*30.5
print(nt)
# Out:
# 美金: 234
# 7137.0

# %%
'合台幣'+str(nt)+'元'
# Out:
# '合台幣7137.0元'

# %% [markdown]
# ## 拍拍機器人

# %%
message=input('>>')
print('拍拍')
# Out:
# >>哭阿
# 拍拍
